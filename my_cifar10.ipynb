# %%
cd my_cifar10
# Out:
# /root/my_cifar10

# %%
mkdir data

# %%
mkdir weights

# %%
mkdir logs

# %%
mkdir models

# %%
cd ~/
# Out:
# /root

# %%
# !git clone https://github.com/ohhan777/jbnu_cifar10.git
# Out:
# Cloning into 'jbnu_cifar10'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 40 (delta 19), reused 34 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (40/40), 20.63 KiB | 10.32 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
import numpy as np
import torch

a = np.array([[1.5, 2, 3], [4, 5, 6]])
b = a.mean(axis=1)
c = torch.tensor(a)  # numpy to tensor
d = c.view(1, -1)
e = d.numpy()  # tensor to numpy
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# [[1.5 2.  3. ]
#  [4.  5.  6. ]]
# [2.16666667 5.        ]
# tensor([[1.5000, 2.0000, 3.0000],
#         [4.0000, 5.0000, 6.0000]], dtype=torch.float64)
# tensor([[1.5000, 2.0000, 3.0000, 4.0000, 5.0000, 6.0000]], dtype=torch.float64)
# [[1.5 2.  3.  4.  5.  6. ]]

# %%
import torch
x = torch.tensor(1., requires_grad=True)
w = torch.tensor(2., requires_grad=True)
b = torch.tensor(3., requires_grad=True)
# Build a computational graph
y = w * x + b    # y = 2 * x + 3
# compute gradients
y.backward()
# Print out the gradients
print(x.grad)
print(w.grad)
print(b.grad)
# Out:
# tensor(2.)
# tensor(1.)
# tensor(1.)

# %%
cd my_cifar10
# Out:
# /root/my_cifar10

# %%
# %%writefile train.py
import argparse

def train(opt):
  epochs = opt.epochs
  batch_size = opt.batch_size
  name = opt.name
  print(epochs)
  print(batch_size)
  print(name)

if __name__ == '__main__':
  parser = argparse.ArgumentParser()
  parser.add_argument('--epochs', type=int, default=200, help='target epochs')
  parser.add_argument('--batch-size', type=int, default=4, help='batch size')
  parser.add_argument('--name', type=str, default='ohhan', help='name for the run')

  opt = parser.parse_args()
  train(opt)
# Out:
# Writing train.py

# %%
# !python train.py --epochs 300 --batch-size 8 --name test
# Out:
# 300
# 8
# test

# %%
# !python train.py --help
# Out:
# usage: train.py [-h] [--epochs EPOCHS] [--batch-size BATCH_SIZE] [--name NAME]
#
# options:
#   -h, --help            show this help message and exit
#   --epochs EPOCHS       target epochs
#   --batch-size BATCH_SIZE
#                         batch size
#   --name NAME           name for the run

# %%
# !git config --global user.name "juyoung0934"
# !git config --global user.email "amkjy2545@gmail.com"
# !cd ~/my_cifar10
# !git init
# !git add .
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/juyoung0934/my_cifar10.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /root/my_cifar10/.git/
# On branch main
# nothing to commit, working tree clean
# error: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address
